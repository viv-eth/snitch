# %%
from tkinter.tix import ButtonBox
from turtle import color
import matplotlib.pyplot as plt
import numpy as np

# %%
# FeedForward
FF_FP64_baseline_cycles = 11379
FF_FP64_optimized_cycles = 6711
FF_FP32_optimized_cycles = 3700
FF_FP16_optimized_cycles = 2095
FF_FP8_optimized_cycles = 1265

# FF_FP64_unrolled_cycles = 2301

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Feed Forward Kernel Computation Speedup', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], FF_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], FF_FP64_optimized_cycles, color='#F29545', label='FP64 Optimized')
ax.bar([2], FF_FP32_optimized_cycles, color='#1269B0', label='FP32 Optimized')
ax.bar([3], FF_FP16_optimized_cycles, color='#48592C', label='FP16 Optimized')
ax.bar([4], FF_FP8_optimized_cycles, color='#A8322C', label='FP8 Optimized')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [FF_FP64_baseline_cycles, FF_FP64_optimized_cycles, FF_FP32_optimized_cycles, FF_FP16_optimized_cycles, FF_FP8_optimized_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, FF_FP64_baseline_cycles, str(round(FF_FP64_baseline_cycles/FF_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.5, FF_FP64_optimized_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP64_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, FF_FP32_optimized_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP32_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, FF_FP16_optimized_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP16_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.4, FF_FP8_optimized_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP8_optimized_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(FF_FP64_baseline_cycles, (0, FF_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(FF_FP64_optimized_cycles, (1, FF_FP64_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP32_optimized_cycles, (2, FF_FP32_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP16_optimized_cycles, (3, FF_FP16_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP8_optimized_cycles, (4, FF_FP8_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [FF_FP64_baseline_cycles, FF_FP64_optimized_cycles, FF_FP32_optimized_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '1265')

# %%
# FeedForward
FF_FP64_baseline_cycles = 11379
FF_FP64_unrolled_cycles = 2301
FF_FP32_unrolled_cycles = 1558
FF_FP16_unrolled_cycles = 1543
FF_FP8_unrolled_cycles = 779

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Feed Forward Kernel Computation Speedup (Unrolled)', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], FF_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], FF_FP64_unrolled_cycles, color='#F29545', label='FP64 unrolled')
ax.bar([2], FF_FP32_unrolled_cycles, color='#1269B0', label='FP32 unrolled')
ax.bar([3], FF_FP16_unrolled_cycles, color='#48592C', label='FP16 unrolled')
ax.bar([4], FF_FP8_unrolled_cycles, color='#A8322C', label='FP8 unrolled')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [FF_FP64_baseline_cycles, FF_FP64_unrolled_cycles, FF_FP32_unrolled_cycles, FF_FP16_unrolled_cycles, FF_FP8_unrolled_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, FF_FP64_baseline_cycles, str(round(FF_FP64_baseline_cycles/FF_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.5, FF_FP64_unrolled_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP64_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, FF_FP32_unrolled_cycles + 200, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP32_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, FF_FP16_unrolled_cycles, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP16_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.2, FF_FP8_unrolled_cycles + 200, 'x'+ str(round(FF_FP64_baseline_cycles/FF_FP8_unrolled_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(FF_FP64_baseline_cycles, (0, FF_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(FF_FP64_unrolled_cycles, (1, FF_FP64_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP32_unrolled_cycles, (2, FF_FP32_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP16_unrolled_cycles, (3, FF_FP16_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(FF_FP8_unrolled_cycles, (4, FF_FP8_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [FF_FP64_baseline_cycles, FF_FP64_unrolled_cycles, FF_FP32_unrolled_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '779')

# %%
# Gradient Update
GU_FP64_baseline_cycles = 13025
GU_FP64_optimized_cycles = 2645
GU_FP32_optimized_cycles = 4731
GU_FP16_optimized_cycles = 2759
GU_FP8_optimized_cycles = 2038

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Gradient Update Kernel Computation Speedup', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], GU_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], GU_FP64_optimized_cycles, color='#F29545', label='FP64 Optimized')
ax.bar([2], GU_FP32_optimized_cycles, color='#1269B0', label='FP32 Optimized')
ax.bar([3], GU_FP16_optimized_cycles, color='#48592C', label='FP16 Optimized')
ax.bar([4], GU_FP8_optimized_cycles, color='#A8322C', label='FP8 Optimized')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [GU_FP64_baseline_cycles, GU_FP64_optimized_cycles, GU_FP32_optimized_cycles, GU_FP16_optimized_cycles, GU_FP8_optimized_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, GU_FP64_baseline_cycles, str(round(GU_FP64_baseline_cycles/GU_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.2, GU_FP64_optimized_cycles + 1500, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP64_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, GU_FP32_optimized_cycles , 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP32_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, GU_FP16_optimized_cycles, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP16_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.4, GU_FP8_optimized_cycles, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP8_optimized_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(GU_FP64_baseline_cycles, (0, GU_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(GU_FP64_optimized_cycles, (1, GU_FP64_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP32_optimized_cycles, (2, GU_FP32_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP16_optimized_cycles, (3, GU_FP16_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP8_optimized_cycles, (4, GU_FP8_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [GU_FP64_baseline_cycles, GU_FP64_optimized_cycles, GU_FP32_optimized_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '2038')

# %%
# Gradient Update
GU_FP64_baseline_cycles = 13025
GU_FP64_unrolled_cycles = 2594
GU_FP32_unrolled_cycles = 2310
GU_FP16_unrolled_cycles = 1543
GU_FP8_unrolled_cycles = 1308

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Gradient Update Kernel Computation Speedup (Unrolled)', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], GU_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], GU_FP64_unrolled_cycles, color='#F29545', label='FP64 unrolled')
ax.bar([2], GU_FP32_unrolled_cycles, color='#1269B0', label='FP32 unrolled')
ax.bar([3], GU_FP16_unrolled_cycles, color='#48592C', label='FP16 unrolled')
ax.bar([4], GU_FP8_unrolled_cycles, color='#A8322C', label='FP8 unrolled')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [GU_FP64_baseline_cycles, GU_FP64_unrolled_cycles, GU_FP32_unrolled_cycles, GU_FP16_unrolled_cycles, GU_FP8_unrolled_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, GU_FP64_baseline_cycles, str(round(GU_FP64_baseline_cycles/GU_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.2, GU_FP64_unrolled_cycles + 1500, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP64_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, GU_FP32_unrolled_cycles , 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP32_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, GU_FP16_unrolled_cycles, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP16_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.2, GU_FP8_unrolled_cycles + 500, 'x'+ str(round(GU_FP64_baseline_cycles/GU_FP8_unrolled_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(GU_FP64_baseline_cycles, (0, GU_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(GU_FP64_unrolled_cycles, (1, GU_FP64_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP32_unrolled_cycles, (2, GU_FP32_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP16_unrolled_cycles, (3, GU_FP16_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(GU_FP8_unrolled_cycles, (4, GU_FP8_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [GU_FP64_baseline_cycles, GU_FP64_unrolled_cycles, GU_FP32_unrolled_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '1308')

# %%
# Training Step
TS_FP64_baseline_cycles = 171711
TS_FP64_optimized_cycles = 2834
TS_FP32_optimized_cycles = 4677
TS_FP16_optimized_cycles = 2861
TS_FP8_optimized_cycles = 1846

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Training Step Kernel Computation Speedup', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], TS_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], TS_FP64_optimized_cycles, color='#F29545', label='FP64 Optimized')
ax.bar([2], TS_FP32_optimized_cycles, color='#1269B0', label='FP32 Optimized')
ax.bar([3], TS_FP16_optimized_cycles, color='#48592C', label='FP16 Optimized')
ax.bar([4], TS_FP8_optimized_cycles, color='#A8322C', label='FP8 Optimized')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [TS_FP64_baseline_cycles, TS_FP64_optimized_cycles, TS_FP32_optimized_cycles, TS_FP16_optimized_cycles, TS_FP8_optimized_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, TS_FP64_baseline_cycles, str(round(TS_FP64_baseline_cycles/TS_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.2, TS_FP64_optimized_cycles + 1500, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP64_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, TS_FP32_optimized_cycles , 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP32_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, TS_FP16_optimized_cycles, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP16_optimized_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.1, TS_FP8_optimized_cycles + 1000, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP8_optimized_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(TS_FP64_baseline_cycles, (0, TS_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(TS_FP64_optimized_cycles, (1, TS_FP64_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP32_optimized_cycles, (2, TS_FP32_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP16_optimized_cycles, (3, TS_FP16_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP8_optimized_cycles, (4, TS_FP8_optimized_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [TS_FP64_baseline_cycles, TS_FP64_optimized_cycles, TS_FP32_optimized_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '1846')

# %%
# Training Step
TS_FP64_baseline_cycles = 171711
TS_FP64_unrolled_cycles = 2722
TS_FP32_unrolled_cycles = 2339
TS_FP16_unrolled_cycles = 1743
TS_FP8_unrolled_cycles = 1213

# %%
# plot the results
from cProfile import label


fig, ax = plt.subplots()
# make plot larger
fig.set_size_inches(18, 15)
ax.set_title('Training Step Kernel Computation Speedup (Unrolled)', fontsize=30)
ax.set_ylabel('Cycles', fontsize=20)
ax.set_xlabel('Floating Point Precision', fontsize=20)
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(['FP64', 'FP64opt', 'FP32opt', 'FP16opt', 'FP8opt'], fontsize=20)
# make y ticks larger
ax.tick_params(axis='y', labelsize=20)
ax.bar([0], TS_FP64_baseline_cycles, color='#910569', label='FP64 Baseline')
ax.bar([1], TS_FP64_unrolled_cycles, color='#F29545', label='FP64 unrolled')
ax.bar([2], TS_FP32_unrolled_cycles, color='#1269B0', label='FP32 unrolled')
ax.bar([3], TS_FP16_unrolled_cycles, color='#48592C', label='FP16 unrolled')
ax.bar([4], TS_FP8_unrolled_cycles, color='#A8322C', label='FP8 unrolled')
# plot connected lines with markersn and add labels
ax.plot([0, 1, 2, 3, 4], [TS_FP64_baseline_cycles, TS_FP64_unrolled_cycles, TS_FP32_unrolled_cycles, TS_FP16_unrolled_cycles, TS_FP8_unrolled_cycles], 'k--', marker='o')
# print relative speedup next to dashed lines
# ax.text(0.5, TS_FP64_baseline_cycles, str(round(TS_FP64_baseline_cycles/TS_FP64_baseline_cycles, 2)), fontsize=20)
ax.text(1.2, TS_FP64_unrolled_cycles + 1500, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP64_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(2.5, TS_FP32_unrolled_cycles + 1500, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP32_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(3.5, TS_FP16_unrolled_cycles+ 1500, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP16_unrolled_cycles, 2)), fontsize=20, color = 'red')
ax.text(4.1, TS_FP8_unrolled_cycles + 1500, 'x'+ str(round(TS_FP64_baseline_cycles/TS_FP8_unrolled_cycles, 2)), fontsize=20, color = 'red')

# show labels
ax.legend(fontsize = 20)
ax.annotate(TS_FP64_baseline_cycles, (0, TS_FP64_baseline_cycles), textcoords="offset points", xytext=(0, 16), ha='center')
ax.annotate(TS_FP64_unrolled_cycles, (1, TS_FP64_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP32_unrolled_cycles, (2, TS_FP32_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP16_unrolled_cycles, (3, TS_FP16_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
ax.annotate(TS_FP8_unrolled_cycles, (4, TS_FP8_unrolled_cycles), textcoords="offset points", xytext=(0, 20), ha='center')
# ax.plot([0, 1, 2], [TS_FP64_baseline_cycles, TS_FP64_unrolled_cycles, TS_FP32_unrolled_cycles], 'k--', marker='o')
# Out:
# Text(0, 20, '1213')
