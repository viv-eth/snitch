# %%
from tkinter.tix import ButtonBox
from turtle import color
import matplotlib.pyplot as plt
import numpy as np

ff_fp64_opt_ur_cycles = np.max([2100, 2103, 2027, 2058, 2006, 1981, 1932, 1877])
print(ff_fp64_opt_ur_cycles)
benchmark_vals = ['fpss_loads', 'fpss_stores','fpss_fpu_rel_occupancy', 'cycles', 'total_ipc']
networks = ['FP64 baseline', 'FP64 opt modified', 'FP64 opt modified with unrolling']
network_part = 'FeedForward'

fpss_loads = [3138, 8, 8]
fpss_stores = [2, 5, 5]
fpss_fpu_rel_occupancy = [0.7138, 0.9894, 0.9895]
cycles = [22723, 6738, 2103]
total_ipc = [0.8315, 0.2522, 0.8181]

# plot fpss_loads as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_loads[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_loads[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_loads[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[0]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_stores as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_stores[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_stores[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_stores[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[1]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_fpu_rel_occupancy as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_fpu_rel_occupancy[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_fpu_rel_occupancy[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_fpu_rel_occupancy[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[2]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot cycles as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, cycles[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, cycles[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, cycles[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[3]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot total_ipc as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, total_ipc[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, total_ipc[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, total_ipc[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[4]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()
# Out:
# 2103

# %%
ff_fp64_opt_ur_cycles = np.max([2100, 2103, 2027, 2058, 2006, 1981, 1932, 1877])
print(ff_fp64_opt_ur_cycles)
benchmark_vals = ['fpss_loads', 'fpss_stores','fpss_fpu_rel_occupancy', 'cycles', 'total_ipc']
networks = ['FP64 baseline', 'FP64 opt modified', 'FP64 opt modified with unrolling']
network_part = 'Gradient Update'

fpss_loads = [1571, 7, 7]
fpss_stores = [1570, 5, 5]
fpss_fpu_rel_occupancy = [0.333, 0.99, 0.99]
cycles = [110843, 5331, 2977]
total_ipc = [0.1707, 0.9141, 0.8468]

# plot fpss_loads as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_loads[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_loads[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_loads[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[0]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_stores as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_stores[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_stores[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_stores[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[1]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_fpu_rel_occupancy as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_fpu_rel_occupancy[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_fpu_rel_occupancy[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_fpu_rel_occupancy[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[2]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot cycles as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, cycles[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, cycles[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, cycles[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[3]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot total_ipc as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, total_ipc[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, total_ipc[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, total_ipc[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[4]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()
# Out:
# 2103

# %%
ff_fp64_opt_ur_cycles = np.max([2100, 2103, 2027, 2058, 2006, 1981, 1932, 1877])
print(ff_fp64_opt_ur_cycles)
benchmark_vals = ['fpss_loads', 'fpss_stores','fpss_fpu_rel_occupancy', 'cycles', 'total_ipc']
networks = ['FP64 baseline', 'FP64 opt modified', 'FP64 opt modified with unrolling']
network_part = 'Training Step'

fpss_loads = [3143, 11, 11]
fpss_stores = [1570, 5, 5]
fpss_fpu_rel_occupancy = [0.0596, 0.9934, 0.9934]
cycles = [370456, 19615, 8391]
total_ipc = [0.1706, 0.7271, 0.7184]

# plot fpss_loads as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_loads[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_loads[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_loads[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[0]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_stores as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_stores[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_stores[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_stores[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[1]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot fpss_fpu_rel_occupancy as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, fpss_fpu_rel_occupancy[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, fpss_fpu_rel_occupancy[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, fpss_fpu_rel_occupancy[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[2]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot cycles as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, cycles[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, cycles[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, cycles[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[3]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()

# plot total_ipc as bar chart
plt.rcParams['figure.figsize'] = (10, 6)

x = np.arange(1)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, total_ipc[0], width/3, label=networks[0], color = '#003f5c')
rects2 = ax.bar(x + width/3, total_ipc[1], width/3, label=networks[1], color = '#ff6361')
rects3 = ax.bar(x, total_ipc[2], width/3, label=networks[2], color = '#ffa600')

ax.set_xticks(x, [benchmark_vals[4]])
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.tight_layout()
plt.show()
